# %% [markdown]
# Implement weather modeling using the quadratic solution with hard coding variables (fixed variable values give in program)

# %%
import matplotlib.pyplot as plt
import numpy as np


def quadratic_model(time):
  # Hard-coded coefficients for the quadratic equation
  a = 0.1
  b = -1
  c = 30

  #quadratic equation representing temperature change
  temperature = a * time**2 + b * time + c
  return temperature


def main():
  # Time values from 0 to 10 (for example)
  time_values = np.linspace(0, 10, 100)
  #calculate temperatures using hard-coded coefficients
  temperature_values = quadratic_model(time_values)

  #plot the temperatures
  plt.plot(time_values, temperature_values)
  plt.xlabel('Time (s)')
  plt.ylabel('Temperature (C)')
  plt.legend()
  plt.title(' temperatures using hard-coded coefficients')
  plt.show()


if __name__ == '__main__':
  main()
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# Implement weather modeling using the quadratic solution with hard coding variables through keyboard input by user

# %%
import matplotlib.pyplot as plt
import numpy as np

def quadratic_temperature_model(time, a, b, c):
    # Quadratic equation representing temperature change
    temperature = a * time**2 + b * time + c
    return temperature

def main():
    # Get user input for coefficients
    a = float(input("Enter the coefficient for a: "))
    b = float(input("Enter the coefficient for b: "))
    c = float(input("Enter the coefficient for c: "))

    # Generate time values from 0 to 10 with 100 points
    time_values = np.linspace(0, 10, 100)

    # Calculate temperatures using user input coefficients
    temperature_values = quadratic_temperature_model(time_values, a, b, c)

    # Plot the temperatures
    plt.plot(time_values, temperature_values)
    plt.xlabel('Time (s)')
    plt.ylabel('Temperature (C)')
    plt.title('Quadratic Temperature Model')
    plt.legend()
    plt.grid(True)
    plt.show()

if __name__ == '__main__':
    main()
# Out:
# Enter the coefficient for a: 2
# Enter the coefficient for b: 3
# Enter the coefficient for c: 5
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# Implement weather modeling using the quadratic solution with hard coding variables read from a file

# %%
import matplotlib.pyplot as plt
import numpy as np
# hard code variables
def quadratic_model(time):
  a,b,c=[10,5,6]
  temperature = a*time*time + b*time + c
  return temperature

time_values=np.linspace(0,10,100)
temperature_hardcoded = quadratic_model(time_values)

plt.plot(time_values,temperature_hardcoded, label='temperature with hard coded coefficients')
plt.xlabel('Time')
plt.ylabel('Temperature')
plt.legend()
plt.title('weather modeling with quadratic equation (read from file)')
plt.show()

# %% [markdown]
# Implement weather modeling using the quadratic solution with hard coding variables for multiple sets of inputs

# %%
import matplotlib.pyplot as plt
import numpy as np

def quadratic_temperature_model(time, a, b, c):
  # Quadratic equation representing temperature change
  temperature = a * time**2 + b * time + c
  return temperature

# List of coefficients sets (a, b, c)
coefficients_list=[
  (0.02, 1.5, 30),
  (0.001, 2, 20),
  (0.03, 1, 45),
]

# Generate time values from 0 to 50 with 1 point increment
time_values = np.linspace(0, 50, 100)

# Plot temperatures for each set of coefficients
for i, (a, b, c) in enumerate(coefficients_list):
  temperatures_values = quadratic_temperature_model(time_values, a, b, c)
  label = f'set {i+1}: a={a}, b={b}, c={c}'
  plt.plot(time_values, temperatures_values, label=label)

# Label and display the plot
plt.xlabel('Time (s)')
plt.ylabel('Temperature (C)')
plt.title('Quadratic Temperature model with multiple sets')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# Implement weather modeling using the quadratic solution with combination of hard coding variables (fixed) and user input through keyboard and specify the type of graphs with values

# %%
import matplotlib.pyplot as plt
import numpy as np

def quadratic_model(time, a, b, c):
    temperature = a * time**2 + b * time + c
    return temperature

# Hard-coded coefficients
hardcoded_a = 1
hardcoded_b = -4
hardcoded_c = 10

# Get user input for additional coefficients
user_a = float(input("Enter coefficient 'a': "))
user_b = float(input("Enter coefficient 'b': "))
user_c = float(input("Enter coefficient 'c': "))

# Time values
time_values = np.linspace(0, 10, 50)

# Calculate temperatures for both hard-coded and user-input coefficients
temperature_hardcoded = quadratic_model(time_values, hardcoded_a, hardcoded_b, hardcoded_c)
temperature_user_input = quadratic_model(time_values, user_a, user_b, user_c)

# Plotting
plt.plot(time_values, temperature_hardcoded, label='Hard-coded coefficients')
plt.plot(time_values, temperature_user_input, label='User-input coefficients')
plt.xlabel('Time')
plt.ylabel('Temperature')
plt.legend()
plt.title('Weather Modeling with Quadratic Equation')
plt.show()
# Out:
# Enter coefficient 'a': 4
# Enter coefficient 'b': 2
# Enter coefficient 'c': 4
